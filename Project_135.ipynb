# %% [markdown]
# <a href="https://colab.research.google.com/github/akarsh9415127958/project-135/blob/main/Project_135.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b2463eae-192d-4e79-aa44-e3e0f51d9353" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2463eae-192d-4e79-aa44-e3e0f51d9353">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving final.csv to final.csv

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("final.csv")
df.head()
# Out:
#    Unnamed: 0       Star Name     Distance        Mass         Radius  \
# 0           0             Sun  0.000015813   1.989e+30    695700000.0
# 1           1          Sirius       0008.6  4.1769e+30   1189647000.0
# 2           2         Canopus         0310  2.9835e+31  49394700000.0
# 3           3  Alpha Centauri       0004.4  2.1879e+30    834840000.0
# 4           4        Arcturus         0037  2.1879e+30  18088200000.0
#
#       Gravity
# 0  274.269161
# 1  196.971800
# 2    0.816115
# 3  209.511165
# 4    0.446296

# %%
mass = df["Mass"].to_list()
radius = df["Radius"].to_list()
distance = df["Distance"].to_list()
gravity = df["Gravity"].to_list()
starName = df["Star Name"].to_list()

# %%
mass.sort()
radius.sort()
gravity.sort()
distance.sort()
starName.sort()

# %%
plt.plot(starName, mass)
plt.title("Star Name VS Mass")
plt.xlabel("Mass")
plt.ylabel("Star Name")
plt.show()

# %%
import plotly.express as px
fig = px.scatter_3d(x = starName, y = mass,z= radius )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.plot(radius, mass)
plt.title("Radius & Mass of the Star")
plt.xlabel("Radius")
plt.ylabel("Mass")
plt.show()

# %%
plt.plot(mass, gravity)

plt.title("Mass VS Gravity")
plt.xlabel("Mass")
plt.ylabel("Gravity")
plt.show()

# %%
plt.scatter(radius, mass)
plt.xlabel("Radius")
plt.ylabel("Mass")
plt.show()

# %%
print(planet_data)

# %%
import plotly.express as px
fig = px.scatter(x=radius,y=mass)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.cluster import KMeans 
import matplotlib.pyplot as plt
import seaborn as sns
X=[]
for index,mass in enumerate(mass):
  temp_list = [radius[index],mass]
  X.append(temp_list)

wcss = []
for i in range(1,11):
  kmeans = KMeans(n_clusters = i,init = "k-means++",random_state = 42)
  kmeans.fit(X)
  wcss.append(kmeans.inertia_)

plt.figure(figsize = (10,5))
sns.lineplot(range(1,11),wcss,marker ="o",color = "red")
plt.title("The Elbow Method")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.show()
